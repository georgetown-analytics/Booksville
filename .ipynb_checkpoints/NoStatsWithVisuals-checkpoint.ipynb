# %% [markdown]
# ## Importing the necesssary Libraries

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import psycopg2 as pg2
import datetime as dt
# package used for converting the data into datetime format
from sklearn.preprocessing import LabelEncoder

from sklearn.feature_selection import RFE, f_regression
from sklearn.linear_model import (LinearRegression, Ridge, Lasso, RandomizedLasso)
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import math

import warnings
warnings.filterwarnings("ignore")

## Execution time counter
#%load_ext autotime

# %% [markdown]
# ## Establish connection to the PostgreSQL database

# %%
conn= pg2.connect('dbname = Booksville user= postgres password =891630 host= 127.0.0.1')
cur=conn.cursor()
df_raw = pd.read_sql_query('select * from public."keepa"', conn)

# %%
#Check the dimension of the raw data to see if its properly imported
print('Starting size of our Dataset ')
df_raw.shape
# Out:
# Starting size of our Dataset
# (100192, 79)

# %%
# Print out count of each datatype in the dataframe
df_raw.dtypes.value_counts()
# Out:
# object    77
# int64      2
# dtype: int64

# %% [markdown]
# ### Price Aggregator
#
# Amazon's listing price for books is stored in one of three columns in keepa's Amazon Price Tracker data dump we obtained for this capstone project. If Amazon is fullfilling the sale, the price comes from amazon_price column. But if the book is sold by a third party seller,  the listing price would be marketplace_new_price for new books and for used ones the listing price will be marketplace_used_price.
#
# We  are  combing the three columns in to one called 'price' and assign its value based on the the given price assignment information.
#
# The aggregator function adds the new column to the dataset and assigns the value that appers first from the following list and finally drops the three columns from the dataset.
#          * amazon_Price
#          * marketplace_new
#          * marketplace_used_price

# %%
def PriceAggregator(original_df):
    
    df=original_df
    # create a copy of the three columns to choose amazon price from
    df_copy=df[['amazon_price','marketplace_new_price','marketplace_used_price']]
    
    # Replace missing price denoted by -1 to Null in all three price columns   
    for item in df_copy:
        df_copy[item].replace('-1',np.nan, inplace=True)
        
    # Add a new column to store the aggregated price with default value of 'amazon_price'         
    df.insert(79,'price',df_copy['amazon_price'].astype('float'))
    
    
    #Loop throgh all three columns to assign non-null value to the newly created price column. 
    #Keep amazon_price as is if not null, otherwise assign marketplace_new_price as the new price. 
    #Where both 'amazon_price' and 'marketplace_new_price' are null, price will be set to 
    #'marketplace_used_price' regardless of its value.
    
    for i in range(df['price'].size):
        if pd.isnull(df['price'][i]):
            if pd.isnull(df_copy['marketplace_new_price'][i]):
                if pd.isnull(df_copy['marketplace_used_price'][i]):
                    pass
                else:
                    df['price'][i]=df_copy['marketplace_used_price'][i]
            else:
                df['price'][i]=df_copy['marketplace_new_price'][i]
        else:
            pass
    
    # Delete records where price value is missing since that is what we are trying to predict 
    df.dropna(subset=['price'], axis=0, inplace=True)
    
    #Reset index after dropping rows with missing price
    df.reset_index(drop= True, inplace=True)
    
    #Delete old price columns after assigning aggregated price to a brand new column    
    df.drop(['amazon_price','marketplace_new_price','marketplace_used_price'], axis=1 , inplace=True)
    
    #Return the a dataframe with a new price column added to the original dataframe
    return df

# %%
df=PriceAggregator(df_raw)

# %%
df.shape
# Out:
# (99658, 77)

# %% [markdown]
# ## Delete duplicate records, if there are any.

# %%
# data size before deleting duplicates
df.shape
# Out:
# (99658, 77)

# %%
df.drop_duplicates(inplace = True)

# %%
# data size after deleting duplicates
df.shape
# Out:
# (99600, 77)

# %% [markdown]
# We can see from .shape() function that there are 99600 unique records with 77 features in the dataset.

# %% [markdown]
# ## Understanding the Data

# %%
# Highlight of the dataframe
df.head(3)
# Out:
#    productType                                               asin  \
# 0            0  154204006X                                    ...
# 1            0  B07JHVJ5SC                                    ...
# 2            0  B00XJ108I6                                    ...
#
#                     author availabilityAmazon         binding brand  \
# 0          Glendy Vanderah                  0       Hardcover
# 1  Sudipta Bardhan-Quallen                 -1  Kindle Edition
# 2              Alan Forbes                 -1  Kindle Edition
#
#   buyBoxSellerIdHistory categoryTree_0 categoryTree_1          categoryTree_2  \
# 0                                Books       Subjects    Literature & Fiction
# 1                                Books       Subjects        Children's Books
# 2                                Books       Subjects  Computers & Technology
#
#     ...                   studio                             title  \
# 0   ...    Lake Union Publishing  Where the Forest Meets the Stars
# 1   ...                                  Purrmaids (6 Book Series)
# 2   ...                             The Joy of PHP (2 Book Series)
#
#   trackingSince          type upc  upcList variationCSV variations sales_rank  \
# 0       4103352     ABIS_BOOK   0                                        1945
# 1       4135600  EBOOK_BUNDLE   0                                           1
# 2       4079996  EBOOK_BUNDLE   0                                           2
#
#     price
# 0  1599.0
# 1  3094.0
# 2   698.0
#
# [3 rows x 77 columns]

# %% [markdown]
# Descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution,

# %%
df.describe(include= 'all' )
# Out:
#          productType                                               asin  \
# count   99600.000000                                              99600
# unique           NaN                                              99467
# top              NaN  1465442375                                    ...
# freq             NaN                                                  2
# mean        0.451878                                                NaN
# std         0.508459                                                NaN
# min         0.000000                                                NaN
# 25%         0.000000                                                NaN
# 50%         0.000000                                                NaN
# 75%         1.000000                                                NaN
# max         4.000000                                                NaN
#
#        author availabilityAmazon            binding  brand  \
# count   99600              99600              99600  99600
# unique  37563                  4                 73   7403
# top                            0  Audible Audiobook
# freq     2060              95037              44619  67295
# mean      NaN                NaN                NaN    NaN
# std       NaN                NaN                NaN    NaN
# min       NaN                NaN                NaN    NaN
# 25%       NaN                NaN                NaN    NaN
# 50%       NaN                NaN                NaN    NaN
# 75%       NaN                NaN                NaN    NaN
# max       NaN                NaN                NaN    NaN
#
#        buyBoxSellerIdHistory categoryTree_0 categoryTree_1  \
# count                  99600          99594          99594
# unique                     1             12             16
# top                                   Books       Subjects
# freq                   99600          99576          99576
# mean                     NaN            NaN            NaN
# std                      NaN            NaN            NaN
# min                      NaN            NaN            NaN
# 25%                      NaN            NaN            NaN
# 50%                      NaN            NaN            NaN
# 75%                      NaN            NaN            NaN
# max                      NaN            NaN            NaN
#
#               categoryTree_2      ...                 studio  \
# count                  96636      ...                  99600
# unique                    46      ...                  10107
# top     Literature & Fiction      ...        Audible Studios
# freq                   17441      ...                   4267
# mean                     NaN      ...                    NaN
# std                      NaN      ...                    NaN
# min                      NaN      ...                    NaN
# 25%                      NaN      ...                    NaN
# 50%                      NaN      ...                    NaN
# 75%                      NaN      ...                    NaN
# max                      NaN      ...                    NaN
#
#                       title trackingSince       type    upc  upcList  \
# count                 99600         99600      99600  99600    92565
# unique                89646         52318         45   7018        1
# top     Think and Grow Rich        119040  ABIS_BOOK      0
# freq                     15          4510      54138  92565    92565
# mean                    NaN           NaN        NaN    NaN      NaN
# std                     NaN           NaN        NaN    NaN      NaN
# min                     NaN           NaN        NaN    NaN      NaN
# 25%                     NaN           NaN        NaN    NaN      NaN
# 50%                     NaN           NaN        NaN    NaN      NaN
# 75%                     NaN           NaN        NaN    NaN      NaN
# max                     NaN           NaN        NaN    NaN      NaN
#
#        variationCSV variations sales_rank          price
# count         99600      99600      99600   99600.000000
# unique           33          1      60449            NaN
# top                                   258            NaN
# freq          99541      99600         11            NaN
# mean            NaN        NaN        NaN    1981.619367
# std             NaN        NaN        NaN    3067.885740
# min             NaN        NaN        NaN       1.000000
# 25%             NaN        NaN        NaN    1045.000000
# 50%             NaN        NaN        NaN    1524.000000
# 75%             NaN        NaN        NaN    2195.000000
# max             NaN        NaN        NaN  500000.000000
#
# [11 rows x 77 columns]

# %% [markdown]
# The data was stored in the PostgreSQL database as text(string) type and running discriptive statistics with .describe() on the dataframe doesnt tell us much until we do the proper type conversion.

# %% [markdown]
#  # Data Wrangling
#
# Data wrangling is the process of converting data from the initial format to a format that may be better for analysis. As part of the wrangling process we are applying different techniques to comeup with a cleaner and complete dataset to apply machine learning. Here are some of he steps we are following;
#     - Identify Missing Values
#     - Replace or Delete Missing Values
#     - Correct Data format
#     - Aggregate highly related categorical values where necessary

# %% [markdown]
# ### Replace missing values with Null Values.

# %% [markdown]
# We will replace every missing values with Numpy Null inorder to keep uniformity and computational speed.

# %%
df.fillna(np.NaN)
df.replace('', np.NaN, inplace=True)

# %%
## count and sort null values in every coulumn in descending order
df.isna().sum().sort_values(ascending=False).to_frame(name='Count of Null Values')
# Out:
#                                       Count of Null Values
# coupon                                               99600
# offers                                               99600
# liveOffersOrder                                      99600
# promotions                                           99600
# buyBoxSellerIdHistory                                99600
# features                                             99600
# upcList                                              99600
# variations                                           99600
# hazardousMaterialType                                99599
# genre                                                99565
# platform                                             99551
# variationCSV                                         99541
# parentAsin                                           99404
# department                                           99087
# size                                                 98585
# model                                                96864
# color                                                96533
# partNumber                                           68582
# mpn                                                  68560
# brand                                                67295
# edition                                              65652
# format                                               52034
# categoryTree_4                                       34740
# categoryTree_3                                        7172
# categoryTree_2                                        2964
# author                                                2060
# languages_0                                            493
# studio                                                 106
# manufacturer                                           106
# publisher                                              106
# ...                                                    ...
# lastRatingUpdate                                         0
# lastUpdate                                               0
# upc                                                      0
# type                                                     0
# trackingSince                                            0
# title                                                    0
# stats_outOfStockPercentageInInterval                     0
# stats_outOfStockPercentage90                             0
# stats_outOfStockPercentage30                             0
# stats_current                                            0
# stats_avg180                                             0
# stats_avg90                                              0
# stats_avg30                                              0
# stats_avg                                                0
# stats_atIntervalStart                                    0
# rootCategory                                             0
# releaseDate                                              0
# publicationDate                                          0
# productGroup                                             0
# packageWidth                                             0
# packageWeight                                            0
# packageQuantity                                          0
# packageLength                                            0
# packageHeight                                            0
# offersSuccessful                                         0
# numberOfPages                                            0
# numberOfItems                                            0
# sales_rank                                               0
# listedSince                                              0
# productType                                              0
#
# [77 rows x 1 columns]

# %% [markdown]
# Null or missing value implies that we dont have information about that feature for an entry in the dataset. We can delete those features that contain Null values for the majority of the recordset because keeping them will not contribute enough signal to the data.

# %%
## create a list of features that contain null value for more than 50% of the records based on the the above observation
Null_features=['coupon','offers','liveOffersOrder','promotions','buyBoxSellerIdHistory','features','upcList','variations',
               'hazardousMaterialType','genre','platform','variationCSV','parentAsin','department','size','model','color'
               ,'partNumber','mpn','brand','edition','format']

# %%
# Column names with Number of Null values contained in them
df[Null_features].isna().sum()
# Out:
# coupon                   99600
# offers                   99600
# liveOffersOrder          99600
# promotions               99600
# buyBoxSellerIdHistory    99600
# features                 99600
# upcList                  99600
# variations               99600
# hazardousMaterialType    99599
# genre                    99565
# platform                 99551
# variationCSV             99541
# parentAsin               99404
# department               99087
# size                     98585
# model                    96864
# color                    96533
# partNumber               68582
# mpn                      68560
# brand                    67295
# edition                  65652
# format                   52034
# dtype: int64

# %% [markdown]
#
# We can delete these features without losing any useful information from our data since more than 50% of the records in the above list contain null values.

# %%
## delete columns that contain very high count null values 
df.drop(Null_features, axis=1, inplace=True)

# %%
# check the shape of the dataset to confirm the features are dropped
df.shape
# Out:
# (99600, 55)

# %% [markdown]
# For the remaining Null values in our data where the total count is relatively small, we will replace them by  a statistically representative values like mean or mode.
#
#   * Mode for categorical values where there is a clear majority or will be replaced 'Unknown'
#   * Mean value is used for numerical columns

# %%
#Assigns column names that contain null values to a list
with_Nulls=df.loc[:, df.isna().sum()!=0].columns.tolist()

# %%
#Lists down the number of null values in every column in descending order
df[with_Nulls].isna().sum().sort_values(ascending=False)
# Out:
# categoryTree_4    34740
# categoryTree_3     7172
# categoryTree_2     2964
# author             2060
# languages_0         493
# studio              106
# publisher           106
# manufacturer        106
# label               106
# binding             102
# imagesCSV            60
# categoryTree_1        6
# categoryTree_0        6
# dtype: int64

# %%
# let's see what kind of information is in each column
df[with_Nulls].head(5)
# Out:
#                     author         binding categoryTree_0 categoryTree_1  \
# 0          Glendy Vanderah       Hardcover          Books       Subjects
# 1  Sudipta Bardhan-Quallen  Kindle Edition          Books       Subjects
# 2              Alan Forbes  Kindle Edition          Books       Subjects
# 3           Michelle Obama       Hardcover          Books       Subjects
# 4              Delia Owens       Hardcover          Books       Subjects
#
#            categoryTree_2     categoryTree_3  \
# 0    Literature & Fiction      Genre Fiction
# 1        Children's Books            Animals
# 2  Computers & Technology        Programming
# 3   Biographies & Memoirs  Ethnic & National
# 4    Literature & Fiction      Genre Fiction
#
#                            categoryTree_4                        imagesCSV  \
# 0                             Family Life                  918hXn4Uy1L.jpg
# 1                                    Cats                D1m%2BnXtoWRS.png
# 2  Software Design, Testing & Engineering                  B1bYlLoRRtS.png
# 3                African-American & Black                  81h2gWPTYJL.jpg
# 4                           Coming of Age  81WWiiLgEyL.jpg,91kNiwGBrAL.jpg
#
#                     label        languages_0            manufacturer  \
# 0   Lake Union Publishing  English,Published   Lake Union Publishing
# 1                     NaN  English,Published                     NaN
# 2                     NaN  English,Published                     NaN
# 3  Crown Publishing Group  English,Published  Crown Publishing Group
# 4      G.P. Putnam's Sons  English,Published      G.P. Putnam's Sons
#
#                 publisher                  studio
# 0   Lake Union Publishing   Lake Union Publishing
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3  Crown Publishing Group  Crown Publishing Group
# 4      G.P. Putnam's Sons      G.P. Putnam's Sons

# %% [markdown]
# The sample shows that the records are mainly comprised of string or categorival values. Lets further divide the series based on the number of missing (Null) values.

# %%
Nulls2Unknown=['categoryTree_4','categoryTree_3','categoryTree_2','author','studio','publisher','manufacturer',
              'label']

# %%
#print out the highest frequency value(Mode) in the given list of features, it only shows the count not the value. 
#Based on the count we can tell if there's a statistical representative mode value to replace the nulls.  
for item in with_Nulls:
    print(f'{item}\t\t{df[item].value_counts().max()}')
# Out:
# author		319
# binding		44619
# categoryTree_0		99576
# categoryTree_1		99576
# categoryTree_2		17441
# categoryTree_3		8216
# categoryTree_4		2704
# imagesCSV		4
# label		4267
# languages_0		95316
# manufacturer		4267
# publisher		4267
# studio		4267

# %% [markdown]
# Given that our data contains 100,000 records we can clearly see the high mode value for some of the features to replace the nulls.

# %%
# The following 3 features have very high Mode value, therefore we'll replace nulls by mode
Nulls2Mode=['languages_0','categoryTree_0','categoryTree_1']

# %%
mode = df.filter(['languages_0','categoryTree_0','categoryTree_1']).mode()
df[Nulls2Mode]=df[Nulls2Mode].fillna(df.mode().iloc[0])

# %% [markdown]
#
#
#
#
#
# For the following features since there is no one single category with a high frequency(Mode) in the group, we are filling the missing(Null) values with 'Unknown'.

# %%
 
NullswithNoMode=df.loc[:, df.isna().sum()!=0].columns.tolist()

# %%
#Based on the top 3 most frequent records in each column, it shows that there is no dominant value that can be used
#as a mode to replace null values. We are therefore replacing null values with 'Unknown'.
for item in NullswithNoMode:
    print(item)
    print(df[item].value_counts().nlargest(3))
    print('Total Number of null values in %s = %d' % (item,df[item].isna().sum()))
    print('')
# Out:
# author
# James Patterson    319
# DK                 306
# Stephen King       186
# Name: author, dtype: int64
# Total Number of null values in author = 2060
#
# binding
# Audible Audiobook    44619
# Paperback            35263
# Hardcover            13342
# Name: binding, dtype: int64
# Total Number of null values in binding = 102
#
# categoryTree_2
# Literature & Fiction    17441
# Children's Books        12742
# Self-Help                9712
# Name: categoryTree_2, dtype: int64
# Total Number of null values in categoryTree_2 = 2964
#
# categoryTree_3
# Genre Fiction       8216
# Christian Living    3547
# Animals             3516
# Name: categoryTree_3, dtype: int64
# Total Number of null values in categoryTree_3 = 7172
#
# categoryTree_4
# Historical       2704
# Family Life      2249
# United States    1988
# Name: categoryTree_4, dtype: int64
# Total Number of null values in categoryTree_4 = 34740
#
# imagesCSV
# 51sV88-zsdL.jpg    4
# 41CVkZuDlVL.jpg    3
# 51lwDPW8IsL.jpg    3
# Name: imagesCSV, dtype: int64
# Total Number of null values in imagesCSV = 60
#
# label
# Audible Studios     4267
# Tantor Audio        3707
# Brilliance Audio    2605
# Name: label, dtype: int64
# Total Number of null values in label = 106
#
# manufacturer
# Audible Studios     4267
# Tantor Audio        3707
# Brilliance Audio    2605
# Name: manufacturer, dtype: int64
# Total Number of null values in manufacturer = 106
#
# publisher
# Audible Studios     4267
# Tantor Audio        3707
# Brilliance Audio    2605
# Name: publisher, dtype: int64
# Total Number of null values in publisher = 106
#
# studio
# Audible Studios     4267
# Tantor Audio        3707
# Brilliance Audio    2605
# Name: studio, dtype: int64
# Total Number of null values in studio = 106

# %%
# Replace nulls with 'Unknown' for multimodel features
df[NullswithNoMode]=df[NullswithNoMode].fillna('Unknown')

# %%
# Check if there are still missing or null values in the dataset
df[df.loc[:, df.isna().sum()!=0].columns].isna().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# We have entirely replaced the null and missing values in the dataset by statistically representative values.

# %% [markdown]
# ## Data Type Conversion

# %%
df.dtypes.value_counts()
# Out:
# object     52
# int64       2
# float64     1
# dtype: int64

# %% [markdown]
# The data imported from postgreSQL to pandas dataframe contains columns as type object(string). Most of those features are actually nemerical values, and we will convert the data type in to the proper format.

# %% [markdown]
# Lets group all those features that are in string (object) format and convert them to numeric

# %%
df.dtypes.value_counts()
# Out:
# object     52
# int64       2
# float64     1
# dtype: int64

# %%
#Convert columns that contain numerical values to numeric data type using pandsas to_numeric
numeric=['availabilityAmazon',
       'ean','hasReviews', 'isEligibleForSuperSaverShipping', 'isEligibleForTradeIn',
       'isRedirectASIN', 'isSNS', 'lastPriceChange','lastRatingUpdate', 'lastUpdate', 'listedSince', 
       'newPriceIsMAP', 'numberOfItems','numberOfPages', 'offersSuccessful', 'packageHeight',
       'packageLength', 'packageQuantity', 'packageWeight', 'packageWidth',
       'publicationDate', 'releaseDate', 'rootCategory','stats_atIntervalStart', 'stats_avg', 'stats_avg30', 'stats_avg90',
       'stats_avg180', 'stats_current', 'stats_outOfStockPercentage30',
       'stats_outOfStockPercentage90', 'stats_outOfStockPercentageInInterval',
       'trackingSince','sales_rank', 'price']
#cols = ['productType','rootCategory','stats_atIntervalStart','availabilityAmazon','hasReviews','isRedirectASIN','isSNS','isEligibleForTradeIn','isEligibleForSuperSaverShipping', 'ean','hasReviews', 'availabilityAmazon','isEligibleForTradeIn','lastPriceChange','lastRatingUpdate','lastUpdate','lastRatingUpdate','lastUpdate','listedSince',"newPriceIsMAP", "numberOfItems", "numberOfPages","packageHeight", "packageLength","packageQuantity", "packageWeight", "packageWidth",'stats_avg', 'stats_avg30', 'stats_avg90', 'stats_avg180', 'stats_current',"stats_outOfStockPercentage30", "stats_outOfStockPercentage90","stats_outOfStockPercentageInInterval","trackingSince",'upc','price','amazon_price', 'marketplace_new_price', 'marketplace_used_price', 'sales_rank']
df[numeric] = df[numeric].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
df.dtypes.value_counts()
# Out:
# float64    35
# object     18
# int64       2
# dtype: int64

# %%
strings=df.loc[:, df.dtypes == np.object].columns.tolist()
print('\n'+ 'Sample of the dataset with only categorical information'+'\n')
df[strings].head(3)
# Out:
# Sample of the dataset with only categorical information
#                                                 asin                   author  \
# 0  154204006X                                    ...          Glendy Vanderah
# 1  B07JHVJ5SC                                    ...  Sudipta Bardhan-Quallen
# 2  B00XJ108I6                                    ...              Alan Forbes
#
#           binding categoryTree_0 categoryTree_1          categoryTree_2  \
# 0       Hardcover          Books       Subjects    Literature & Fiction
# 1  Kindle Edition          Books       Subjects        Children's Books
# 2  Kindle Edition          Books       Subjects  Computers & Technology
#
#   categoryTree_3                          categoryTree_4          imagesCSV  \
# 0  Genre Fiction                             Family Life    918hXn4Uy1L.jpg
# 1        Animals                                    Cats  D1m%2BnXtoWRS.png
# 2    Programming  Software Design, Testing & Engineering    B1bYlLoRRtS.png
#
#                    label        languages_0           manufacturer  \
# 0  Lake Union Publishing  English,Published  Lake Union Publishing
# 1                Unknown  English,Published                Unknown
# 2                Unknown  English,Published                Unknown
#
#    productGroup              publisher                 studio  \
# 0          Book  Lake Union Publishing  Lake Union Publishing
# 1  Ebook Bundle                Unknown                Unknown
# 2  Ebook Bundle                Unknown                Unknown
#
#                               title          type upc
# 0  Where the Forest Meets the Stars     ABIS_BOOK   0
# 1         Purrmaids (6 Book Series)  EBOOK_BUNDLE   0
# 2    The Joy of PHP (2 Book Series)  EBOOK_BUNDLE   0

# %% [markdown]
# We can delete 'asin', 'ean' and 'imageCSV' columns since the information contained in them is not characteristic discription of books.

# %%
df.drop(['asin','imagesCSV','ean', 'upc'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (99600, 51)

# %%
df.dtypes.value_counts()
# Out:
# float64    34
# object     15
# int64       2
# dtype: int64

# %%
# Print features that are of object type
df.loc[:, df.dtypes == np.object].columns
# Out:
# Index(['author', 'binding', 'categoryTree_0', 'categoryTree_1',
#        'categoryTree_2', 'categoryTree_3', 'categoryTree_4', 'label',
#        'languages_0', 'manufacturer', 'productGroup', 'publisher', 'studio',
#        'title', 'type'],
#       dtype='object')

# %% [markdown]
#
#
# Information regarding what language a book is written in and whether its an original print or translated version is recorded in the 'language_0' column. These two information are separated by comma, this column can be split into two parts and stored separately inorder to reduce categorical data we have to encode later.

# %%
df['languages_0'].head(5)
# Out:
# 0    English,Published
# 1    English,Published
# 2    English,Published
# 3    English,Published
# 4    English,Published
# Name: languages_0, dtype: object

# %%
new = df['languages_0'].str.split(",", n = 1, expand = True)

# %%
df['language_1']=new[0]
df['language_2']=new[1]

# %%
# reduced categories froom 9 to 6 grouping related categories together
#df['language_1'].value_counts().to_frame()

# %%
#group English, english and Middle English to one categry
df['language_1'].replace(('English', 'english','Middle English'),'English', inplace = True)

#grouping Spanish,Portuguese and Latin under "Spanish"
df['language_1'].replace(('Spanish', 'Portuguese','Latin'),'Spanish', inplace = True)

#grouping Chinese, mandarin Chinese and simplified chinese to Chinese 
df['language_1'].replace(('Simplified Chinese', 'Mandarin Chinese','Chinese'),'Chinese', inplace = True)

#grouping Arabic,Hebrew and Turkish under Middle Eastern
df['language_1'].replace(('Arabic', 'Hebrew','Turkish'),'Middle Eastern', inplace = True)

# group languages with single entry record in to one group called 'Others'
df['language_1'].replace(('Hindi', 'Scots','Filipino','Malay','Dutch','Greek','Korean','Romanian','Czech'),'Others', inplace = True)


#grouping Danish and Norwegian into one group of 'Scandinavian'  
df['language_1'].replace(('Danish', 'Norwegian'),'Scandinavian', inplace=True)

# %%
#replaced ('published','Published,Dolby Digital 1.0','Published,DTS-HD 5.1') by Published
df['language_2'].replace(('published','Published,Dolby Digital 1.0','Published,DTS-HD 5.1'),'Published', inplace=True)

# %%
df[['language_1','language_2']].head(5)
# Out:
#   language_1 language_2
# 0    English  Published
# 1    English  Published
# 2    English  Published
# 3    English  Published
# 4    English  Published

# %%
#Since we have copied the information into new columns we can delete the languages_0 column
df.drop(['languages_0'], axis=1 , inplace=True)

# %%
#df.columns

# %%
df.shape
# Out:
# (99600, 52)

# %%
#Cleaning binding column
df.binding.value_counts()
# Out:
# Audible Audiobook              44619
# Paperback                      35263
# Hardcover                      13342
# Board book                      1633
# Mass Market Paperback           1260
# Spiral-bound                     611
# Cards                            459
# Calendar                         326
# Imitation Leather                283
# Map                              201
# Pamphlet                         187
# Perfect Paperback                162
# Diary                            132
# Audio CD                         116
# Unknown                          102
# Misc. Supplies                    90
# Sheet music                       84
# Leather Bound                     79
# Flexibound                        76
# Hardcover-spiral                  53
# Loose Leaf                        52
# Game                              47
# Plastic Comb                      40
# Software Download                 39
# Electronics                       30
# Bonded Leather                    27
# Single Issue Magazine             26
# Bookmark                          24
# Ring-bound                        17
# Staple Bound                      17
#                                ...
# Kindle Edition                     7
# Kitchen                            6
# Rag Book                           5
# Textbook Binding                   5
# Comic                              5
# Vinyl Bound                        4
# Automotive                         3
# CD-ROM                             2
# JP Oversized                       2
# Album                              2
# Turtleback                         2
# Jewelry                            2
# Workbook                           2
# Wireless Phone Accessory           2
# Print on Demand (Paperback)        2
# Poster                             2
# Paperback Bunko                    2
# School & Library Binding           1
# Lawn & Patio                       1
# DVD-ROM                            1
# Personal Computers                 1
# Audio CD Library Binding           1
# Blu-ray                            1
# Health and Beauty                  1
# Pocket Book                        1
# Video Game                         1
# Print Magazine                     1
# Thread Bound                       1
# Puzzle                             1
# Roughcut                           1
# Name: binding, Length: 73, dtype: int64

# %% [markdown]
# The binding column contains 73 differnt categories that are mostly related and some of them contain very small elements, we will aggregate closely related categories to reduce the dimension of our variables to avoid curse of dimensionality

# %%
df.binding.nunique()
# Out:
# 73

# %%
# create a dictionary of identiacal items to create a group an aggregate category 
dict={'Unknown':['Printed Access Code', 'Unknown','Health and Beauty', 'Lawn & Patio', 'Workbook', 'Kitchen', 'Automotive', 'Jewelry'],
     'spiral':[ 'Spiral-bound', 'Staple Bound', 'Ring-bound', 'Plastic Comb', 'Loose Leaf', 'Thread Bound'],
     'magazines':[ 'Journal', 'Single Issue Magazine', 'Print Magazine'],
     'audios':[ 'Audible Audiobook', 'Audio CD', 'DVD', 'Album', 'MP3 CD', 'Audio CD Library Binding'],
     'digital_prints':[ 'CD-ROM', 'Blu-ray', 'DVD-ROM', 'Kindle Edition', 'Video Game', 'Sheet music', 'Software Download',
 'Personal Computers', 'Electronics', 'Game', 'Wireless Phone Accessory'],
     'hardcovers':['Hardcover', 'Hardcover-spiral', 'Turtleback', 'Roughcut'],
     'others':[ 'Cards', 'Pamphlet', 'Calendar', 'Map', 'Stationery', 'Accessory', 'Misc. Supplies', 'Office Product', 'Poster',
 'Wall Chart', 'Bookmark', 'JP Oversized'],
     'paperbacks':[ 'Paperback', 'Perfect Paperback', 'Mass Market Paperback', 'Flexibound', 'Print on Demand (Paperback)',
 'Comic', 'Puzzle', 'Paperback Bunko'],
     'leather_bonded':[ 'Bonded Leather', 'Leather Bound', 'Imitation Leather', 'Vinyl Bound'],
     'board_book':[ 'Board book', 'Baby Product', 'Toy', 'Rag Book', 'Card Book', 'Bath Book', 'Pocket Book'],
     'schoolLibrary_binding':[ 'School & Library Binding', 'Library Binding', 'Textbook Binding']}

# %%
for key,val in dict.items():
    df.binding.replace(val,key, inplace=True)

# %%
df.binding.value_counts()
# Out:
# audios                   44757
# paperbacks               36771
# hardcovers               13398
# board_book                1679
# others                    1333
# spiral                     738
# leather_bonded             393
# digital_prints             215
# Diary                      132
# Unknown                    126
# magazines                   40
# schoolLibrary_binding       18
# Name: binding, dtype: int64

# %%
df.head()
# Out:
#    productType                   author  availabilityAmazon         binding  \
# 0            0          Glendy Vanderah                 0.0      hardcovers
# 1            0  Sudipta Bardhan-Quallen                -1.0  digital_prints
# 2            0              Alan Forbes                -1.0  digital_prints
# 3            0           Michelle Obama                 0.0      hardcovers
# 4            0              Delia Owens                 0.0      hardcovers
#
#   categoryTree_0 categoryTree_1          categoryTree_2     categoryTree_3  \
# 0          Books       Subjects    Literature & Fiction      Genre Fiction
# 1          Books       Subjects        Children's Books            Animals
# 2          Books       Subjects  Computers & Technology        Programming
# 3          Books       Subjects   Biographies & Memoirs  Ethnic & National
# 4          Books       Subjects    Literature & Fiction      Genre Fiction
#
#                            categoryTree_4  domainId     ...      \
# 0                             Family Life         1     ...
# 1                                    Cats         1     ...
# 2  Software Design, Testing & Engineering         1     ...
# 3                African-American & Black         1     ...
# 4                           Coming of Age         1     ...
#
#    stats_outOfStockPercentage90  stats_outOfStockPercentageInInterval  \
# 0                           0.0                                   0.0
# 1                         100.0                                 100.0
# 2                         100.0                                 100.0
# 3                           0.0                                   1.0
# 4                           0.0                                   0.0
#
#                    studio                             title  trackingSince  \
# 0   Lake Union Publishing  Where the Forest Meets the Stars      4103352.0
# 1                 Unknown         Purrmaids (6 Book Series)      4135600.0
# 2                 Unknown    The Joy of PHP (2 Book Series)      4079996.0
# 3  Crown Publishing Group                          Becoming      3762476.0
# 4      G.P. Putnam's Sons           Where the Crawdads Sing      3836972.0
#
#            type  sales_rank   price  language_1  language_2
# 0     ABIS_BOOK      1945.0  1599.0     English   Published
# 1  EBOOK_BUNDLE         1.0  3094.0     English   Published
# 2  EBOOK_BUNDLE         2.0   698.0     English   Published
# 3     ABIS_BOOK      3568.0  1788.0     English   Published
# 4     ABIS_BOOK        32.0  1670.0     English   Published
#
# [5 rows x 52 columns]

# %%
#catTree_under10.categoryTree_2.values= 'Other'
def groupUnder10(x):
    cond = df[x].value_counts()
    threshold = 10
    df[x] = np.where(df[x].isin(cond.index[cond > threshold ]), df[x], 'Others')
    print('All the different categories that contain less than 10 items in the %s column are grouped together and renamed to "Others".' %x)

# %%
df[['categoryTree_1','categoryTree_2','categoryTree_3','categoryTree_4']].nunique()
# Out:
# categoryTree_1      16
# categoryTree_2      47
# categoryTree_3     370
# categoryTree_4    1618
# dtype: int64

# %%
groupUnder10('categoryTree_2')
# Out:
# All the different categories that contain less than 10 items in the categoryTree_2 column are grouped together and renamed to "Others".

# %%
#group under 10 counts in to one for categoryTree_3 column
groupUnder10('categoryTree_3')
# Out:
# All the different categories that contain less than 10 items in the categoryTree_3 column are grouped together and renamed to "Others".

# %%
groupUnder10('categoryTree_4')
# Out:
# All the different categories that contain less than 10 items in the categoryTree_4 column are grouped together and renamed to "Others".

# %%
df[['categoryTree_0','categoryTree_1','categoryTree_2','categoryTree_3','categoryTree_4']].nunique()
# Out:
# categoryTree_0     12
# categoryTree_1     16
# categoryTree_2     34
# categoryTree_3    272
# categoryTree_4    680
# dtype: int64

# %%
## Some features are duplicated within the dataset, lets delete those duplicated columns

# %%
## Delete duplicated features

duplicates=df[['label', 'manufacturer', 'publisher', 'studio']]

# %%
df['label'].equals(df['manufacturer'])
# Out:
# True

# %%
df['label'].equals(duplicates['publisher'])
# Out:
# True

# %%
df['label'].equals(duplicates['studio'])
# Out:
# True

# %%
df[df.duplicated(['label', 'manufacturer', 'publisher', 'studio'])]
# Out:
#        productType                    author  availabilityAmazon  \
# 2                0               Alan Forbes                -1.0
# 5                0         Richard K. Morgan                -1.0
# 9                0             Mary Casanova                -1.0
# 11               0               Scott Pratt                -1.0
# 13               1             Rachel Hollis                 0.0
# 14               0            Lee H. Haywood                -1.0
# 15               0  Jessica Amanda Salmonson                -1.0
# 20               0            Lysa TerKeurst                 0.0
# 23               1               James Clear                 0.0
# 25               0        MD Brian J. Levine                -1.0
# 29               0             David Goggins                 0.0
# 36               0           Benjamin Dreyer                 0.0
# 38               1              J.K. Rowling                 0.0
# 39               1         Yuval Noah Harari                 0.0
# 41               1             Rachel Hollis                 0.0
# 42               1               Marie Kondo                 0.0
# 44               1       George R. R. Martin                 0.0
# 46               1              J.K. Rowling                 0.0
# 47               0               Marie Kond?                 0.0
# 50               1              J.K. Rowling                 0.0
# 56               1              J.K. Rowling                 0.0
# 60               1          Stephen R. Covey                 0.0
# 61               1              J.K. Rowling                 0.0
# 62               1              J.K. Rowling                 0.0
# 63               1                Adam Grant                 0.0
# 64               0           Naomi Kleinberg                 0.0
# 65               0                 Jen Fisch                 0.0
# 67               1            Liane Moriarty                 0.0
# 68               0  Bessel van der Kolk M.D.                 0.0
# 69               1               Susan Trott                 0.0
# ...            ...                       ...                 ...
# 99625            0                Clint Hill                 1.0
# 99626            0   Catherine Drinker Bowen                 0.0
# 99627            0                  Warman's                 0.0
# 99628            0      Renee Prajer RDH  MS                 1.0
# 99629            1                K.L. Going                 0.0
# 99630            0          Michael Connelly                 0.0
# 99631            0            Ray H Garrison                 0.0
# 99633            0               Salena Zito                 0.0
# 99634            0             Dennis Prager                 0.0
# 99635            1          Lisa Chamberlain                 0.0
# 99636            1           Terry Pratchett                 0.0
# 99637            0               Geoff Benge                 0.0
# 99638            0                  Apuleius                 0.0
# 99639            0          Jessica Williams                 0.0
# 99640            0              William W Li                 1.0
# 99641            1                Seth Godin                 0.0
# 99642            0            Bert Mendelson                 0.0
# 99643            1  Diane McKinney-Whetstone                 0.0
# 99644            0           Diane Gilleland                 0.0
# 99646            0           Richard Rushing                 0.0
# 99647            1              Amanda Quick                 0.0
# 99648            1              J.K. Rowling                 0.0
# 99649            1              Loretta Ross                 0.0
# 99650            0           Jessica M. Utts                 2.0
# 99651            0          Jillian Michaels                 0.0
# 99652            0                 Zondervan                 0.0
# 99653            0        Anthony Ray Hinton                -1.0
# 99654            0             Claire Weekes                 0.0
# 99656            1          Michael P. Foley                 0.0
# 99657            0             Gay Hendricks                 0.0
#
#               binding categoryTree_0 categoryTree_1  \
# 2      digital_prints          Books       Subjects
# 5      digital_prints          Books       Subjects
# 9      digital_prints          Books       Subjects
# 11     digital_prints          Books       Subjects
# 13             audios          Books       Subjects
# 14     digital_prints          Books       Subjects
# 15     digital_prints          Books       Subjects
# 20         hardcovers          Books       Subjects
# 23             audios          Books       Subjects
# 25         paperbacks          Books       Subjects
# 29         hardcovers          Books       Subjects
# 36         hardcovers          Books       Subjects
# 38             audios          Books       Subjects
# 39             audios          Books       Subjects
# 41             audios          Books       Subjects
# 42             audios          Books       Subjects
# 44             audios          Books       Subjects
# 46             audios          Books       Subjects
# 47         hardcovers          Books       Subjects
# 50             audios          Books       Subjects
# 56             audios          Books       Subjects
# 60             audios          Books       Subjects
# 61             audios          Books       Subjects
# 62             audios          Books       Subjects
# 63             audios          Books       Subjects
# 64         board_book          Books       Subjects
# 65         paperbacks          Books       Subjects
# 67             audios          Books       Subjects
# 68         paperbacks          Books       Subjects
# 69             audios          Books       Subjects
# ...               ...            ...            ...
# 99625      paperbacks          Books       Subjects
# 99626      paperbacks          Books       Subjects
# 99627      hardcovers          Books       Subjects
# 99628          spiral          Books       Subjects
# 99629          audios          Books       Subjects
# 99630      paperbacks          Books       Subjects
# 99631      paperbacks          Books       Subjects
# 99633      hardcovers          Books       Subjects
# 99634      paperbacks          Books       Subjects
# 99635          audios          Books       Subjects
# 99636          audios          Books       Subjects
# 99637      paperbacks          Books       Subjects
# 99638      paperbacks          Books       Subjects
# 99639      paperbacks          Books       Subjects
# 99640      hardcovers          Books       Subjects
# 99641          audios          Books       Subjects
# 99642      paperbacks          Books       Subjects
# 99643          audios          Books       Subjects
# 99644      paperbacks          Books       Subjects
# 99646      hardcovers          Books       Subjects
# 99647          audios          Books       Subjects
# 99648          audios          Books       Subjects
# 99649          audios          Books       Subjects
# 99650      paperbacks          Books       Subjects
# 99651      paperbacks          Books       Subjects
# 99652  leather_bonded          Books       Subjects
# 99653      paperbacks          Books       Subjects
# 99654      paperbacks          Books       Subjects
# 99656          audios          Books       Subjects
# 99657      paperbacks          Books       Subjects
#
#                      categoryTree_2                categoryTree_3  \
# 2            Computers & Technology                   Programming
# 5              Literature & Fiction                 Genre Fiction
# 9                  Children's Books    Growing Up & Facts of Life
# 11     Mystery, Thriller & Suspense          Thrillers & Suspense
# 13                        Self-Help                  Motivational
# 14             Literature & Fiction                 Genre Fiction
# 15             Literature & Fiction                 Genre Fiction
# 20         Christian Books & Bibles              Christian Living
# 23                        Self-Help       Personal Transformation
# 25                          Unknown                       Unknown
# 29        Health, Fitness & Dieting                       Unknown
# 36            Humor & Entertainment                         Humor
# 38               Teen & Young Adult          Literature & Fiction
# 39                          History                         World
# 41                        Self-Help                  Motivational
# 42                        Self-Help                  Motivational
# 44             Literature & Fiction                 Genre Fiction
# 46               Teen & Young Adult          Literature & Fiction
# 47                        Self-Help                  Motivational
# 50               Teen & Young Adult          Literature & Fiction
# 56               Teen & Young Adult          Literature & Fiction
# 60                        Self-Help                  Motivational
# 61               Teen & Young Adult          Literature & Fiction
# 62               Teen & Young Adult          Literature & Fiction
# 63            Biographies & Memoirs                       Memoirs
# 64                 Children's Books    Growing Up & Facts of Life
# 65           Cookbooks, Food & Wine      Regional & International
# 67             Literature & Fiction                 Genre Fiction
# 68        Health, Fitness & Dieting                 Mental Health
# 69             Literature & Fiction                      Literary
# ...                             ...                           ...
# 99625         Biographies & Memoirs                    Historical
# 99626                       History                      Americas
# 99627        Crafts, Hobbies & Home       Antiques & Collectibles
# 99628                 Medical Books                     Dentistry
# 99629     Health, Fitness & Dieting                       Unknown
# 99630          Literature & Fiction                 United States
# 99631              Business & Money                    Accounting
# 99633                       History                      Americas
# 99634    Politics & Social Sciences         Politics & Government
# 99635       Religion & Spirituality        New Age & Spirituality
# 99636     Science Fiction & Fantasy                       Fantasy
# 99637         Biographies & Memoirs      Leaders & Notable People
# 99638         Humor & Entertainment                         Humor
# 99639                     Reference     Words, Language & Grammar
# 99640     Health, Fitness & Dieting          Alternative Medicine
# 99641              Business & Money       Management & Leadership
# 99642                Science & Math                   Mathematics
# 99643          Literature & Fiction                 Genre Fiction
# 99644        Crafts, Hobbies & Home              Crafts & Hobbies
# 99646       Religion & Spirituality                       Unknown
# 99647                       Romance                  Contemporary
# 99648          Literature & Fiction            Action & Adventure
# 99649          Literature & Fiction                      Literary
# 99650                Science & Math                   Mathematics
# 99651     Health, Fitness & Dieting            Exercise & Fitness
# 99652      Christian Books & Bibles                        Bibles
# 99653                       Unknown                       Unknown
# 99654                     Self-Help             Stress Management
# 99656      Christian Books & Bibles  Churches & Church Leadership
# 99657                     Self-Help       Personal Transformation
#
#                                 categoryTree_4  domainId        ...          \
# 2       Software Design, Testing & Engineering         1        ...
# 5                                          War         1        ...
# 9      Friendship, Social Skills & School Life         1        ...
# 11                                       Legal         1        ...
# 13                                     Unknown         1        ...
# 14                                      Horror         1        ...
# 15                                  Historical         1        ...
# 20                              Women's Issues         1        ...
# 23                                     Unknown         1        ...
# 25                                     Unknown         1        ...
# 29                                     Unknown         1        ...
# 36                                      Essays         1        ...
# 38                                    Humorous         1        ...
# 39                      Civilization & Culture         1        ...
# 41                                     Unknown         1        ...
# 42                                     Unknown         1        ...
# 44                                      Horror         1        ...
# 46                      Social & Family Issues         1        ...
# 47                                     Unknown         1        ...
# 50                      Social & Family Issues         1        ...
# 56                                    Humorous         1        ...
# 60                                     Unknown         1        ...
# 61                                    Humorous         1        ...
# 62                      Social & Family Issues         1        ...
# 63                                     Unknown         1        ...
# 64                                      Health         1        ...
# 65                                      Others         1        ...
# 67                                 Family Life         1        ...
# 68                       Personality Disorders         1        ...
# 69                                     Unknown         1        ...
# ...                                        ...       ...        ...
# 99625                            United States         1        ...
# 99626                            United States         1        ...
# 99627                           Coins & Medals         1        ...
# 99628                                   Others         1        ...
# 99629                                  Unknown         1        ...
# 99630                                  Unknown         1        ...
# 99631                               Managerial         1        ...
# 99633                            United States         1        ...
# 99634                   Ideologies & Doctrines         1        ...
# 99635             Wicca, Witchcraft & Paganism         1        ...
# 99636                                     Epic         1        ...
# 99637                                Religious         1        ...
# 99638                                   Satire         1        ...
# 99639                           Reading Skills         1        ...
# 99640                                  Healing         1        ...
# 99641                               Management         1        ...
# 99642                      Geometry & Topology         1        ...
# 99643                               Historical         1        ...
# 99644            Needlecrafts & Textile Crafts         1        ...
# 99646                                  Unknown         1        ...
# 99647                                  Unknown         1        ...
# 99648                                  Fantasy         1        ...
# 99649                                  Unknown         1        ...
# 99650                                  Applied         1        ...
# 99651                                   Others         1        ...
# 99652                                  Unknown         1        ...
# 99653                                  Unknown         1        ...
# 99654                                  Unknown         1        ...
# 99656                           Church History         1        ...
# 99657                                  Unknown         1        ...
#
#        stats_outOfStockPercentage90  stats_outOfStockPercentageInInterval  \
# 2                             100.0                                 100.0
# 5                             100.0                                 100.0
# 9                             100.0                                 100.0
# 11                            100.0                                 100.0
# 13                              1.0                                   1.0
# 14                            100.0                                 100.0
# 15                            100.0                                 100.0
# 20                              0.0                                   0.0
# 23                              0.0                                   0.0
# 25                            100.0                                 100.0
# 29                              1.0                                   1.0
# 36                              0.0                                   0.0
# 38                              1.0                                   1.0
# 39                              0.0                                   0.0
# 41                              1.0                                   1.0
# 42                              1.0                                   1.0
# 44                              1.0                                   1.0
# 46                              1.0                                   1.0
# 47                              0.0                                   0.0
# 50                              1.0                                   1.0
# 56                              1.0                                   1.0
# 60                              1.0                                   1.0
# 61                              0.0                                   0.0
# 62                              0.0                                   0.0
# 63                             54.0                                  29.0
# 64                              0.0                                   0.0
# 65                              0.0                                   0.0
# 67                              0.0                                   0.0
# 68                              0.0                                   0.0
# 69                             52.0                                  26.0
# ...                             ...                                   ...
# 99625                           0.0                                   4.0
# 99626                           0.0                                   0.0
# 99627                           0.0                                   0.0
# 99628                          19.0                                  10.0
# 99629                           0.0                                   0.0
# 99630                           0.0                                   0.0
# 99631                           0.0                                   0.0
# 99633                           0.0                                   0.0
# 99634                           0.0                                   0.0
# 99635                           0.0                                   0.0
# 99636                           0.0                                   0.0
# 99637                           0.0                                   0.0
# 99638                           0.0                                   0.0
# 99639                           0.0                                   0.0
# 99640                           0.0                                   0.0
# 99641                           0.0                                   0.0
# 99642                           0.0                                   0.0
# 99643                           0.0                                   0.0
# 99644                           0.0                                   0.0
# 99646                           0.0                                   0.0
# 99647                           0.0                                   0.0
# 99648                           0.0                                   0.0
# 99649                           0.0                                   0.0
# 99650                           0.0                                   4.0
# 99651                           0.0                                   0.0
# 99652                           0.0                                   0.0
# 99653                         100.0                                 100.0
# 99654                           0.0                                   1.0
# 99656                           0.0                                   0.0
# 99657                          41.0                                  24.0
#
#                                      studio  \
# 2                                   Unknown
# 5                                   Unknown
# 9                                   Unknown
# 11                                  Unknown
# 13                            Thomas Nelson
# 14                                  Unknown
# 15                                  Unknown
# 20                            Thomas Nelson
# 23                            Penguin Audio
# 25                                  Unknown
# 29                     Lioncrest Publishing
# 36                             Random House
# 38                    Pottermore Publishing
# 39                              HarperAudio
# 41                 HarperCollins Leadership
# 42                             Tantor Audio
# 44                       Random House Audio
# 46                    Pottermore Publishing
# 47                          Ten Speed Press
# 50                    Pottermore Publishing
# 56                    Pottermore Publishing
# 60                   Simon & Schuster Audio
# 61                    Pottermore Publishing
# 62                    Pottermore Publishing
# 63                          Audible Studios
# 64     Random House Books for Young Readers
# 65                          Rockridge Press
# 67                          Macmillan Audio
# 68                            Penguin Books
# 69                          Audible Studios
# ...                                     ...
# 99625                         Gallery Books
# 99626                        Back Bay Books
# 99627                   Krause Publications
# 99628                    F.A. Davis Company
# 99629                     Listening Library
# 99630              Grand Central Publishing
# 99631                 McGraw-Hill Education
# 99633                           Crown Forum
# 99634                       Broadside Books
# 99635                      Lisa Chamberlain
# 99636               Random House Audiobooks
# 99637                       YWAM Publishing
# 99638                      Penguin Classics
# 99639                            Heinle ELT
# 99640              Grand Central Publishing
# 99641                      Brilliance Audio
# 99642                    Dover Publications
# 99643                        Recorded Books
# 99644                Storey Publishing, LLC
# 99646                       Banner of Truth
# 99647                       Recorded Books
# 99648                 Pottermore Publishing
# 99649                       Audible Studios
# 99650                      Cengage Learning
# 99651                          Rodale Books
# 99652                            Zonderkidz
# 99653                       Random House Uk
# 99654                 Harpercollins Pub Ltd
# 99656                Blackstone Audio, Inc.
# 99657                           Atria Books
#
#                                                    title  trackingSince  \
# 2                         The Joy of PHP (2 Book Series)      4079996.0
# 5                  Takeshi Kovacs Novels (3 Book Series)      3802278.0
# 9                 Grace 3-Book Boxed Set (3 Book Series)      3903832.0
# 11                         Darren Street (3 Book Series)      3823576.0
# 13     Girl, Wash Your Face: Stop Believing the Lies ...      3783088.0
# 14         The Gods and Kings Chronicles (3 Book Series)      3757300.0
# 15                  The Tomoe Gozen Saga (3 Book Series)      3904964.0
# 20     It's Not Supposed to Be This Way: Finding Unex...      3883132.0
# 23       Atomic Habits: Tiny Changes, Remarkable Results      4006960.0
# 25                   EMRA Antibiotic Guide, 17th Edition      3055304.0
# 29     Can't Hurt Me: Master Your Mind and Defy the Odds      4035968.0
# 36     Dreyer's English: An Utterly Correct Guide to ...      3886014.0
# 38       Harry Potter and the Chamber of Secrets, Book 2      3795484.0
# 39                 Sapiens: A Brief History of Humankind      3798098.0
# 41     Girl, Stop Apologizing (Audible Exclusive Edit...      3978548.0
# 42     The Life-Changing Magic of Tidying Up: The Jap...      3808292.0
# 44     A Game of Thrones: A Song of Ice and Fire, Book 1      3798108.0
# 46      Harry Potter and the Prisoner of Azkaban, Book 3      3798718.0
# 47     Spark Joy: An Illustrated Master Class on the ...      2356368.0
# 50           Harry Potter and the Goblet of Fire, Book 4      3798718.0
# 56     Harry Potter and the Order of the Phoenix, Book 5      3798718.0
# 60     The 7 Habits of Highly Effective People: Power...      3798554.0
# 61        Harry Potter and the Half-Blood Prince, Book 6      3797872.0
# 62          Harry Potter and the Deathly Hallows, Book 7      3796800.0
# 63                       Power Moves: Lessons from Davos      4060296.0
# 64       P is for Potty! (Sesame Street) (Lift-the-Flap)      1708140.0
# 65     The Easy 5-Ingredient Ketogenic Diet Cookbook:...      3622652.0
# 67                                Nine Perfect Strangers      3932040.0
# 68     The Body Keeps the Score: Brain, Mind, and Bod...      2172600.0
# 69     The Man on the Mountaintop: An Audible Origina...      3976188.0
# ...                                                  ...            ...
# 99625                              Five Days in November      2403161.0
# 99626  Miracle At Philadelphia: The Story of the Cons...       119040.0
# 99627  State Quarters 1999-2009 Deluxe Collector's Fo...       121500.0
# 99628  DH Notes: Dental Hygienist's Chairside Pocket ...      3184148.0
# 99629                     The Liberation of Gabriel King      3809488.0
# 99630              The Reversal (A Lincoln Lawyer Novel)      3018198.0
# 99631               Loose Leaf for Managerial Accounting      2925712.0
# 99633  The Great Revolt: Inside the Populist Coalitio...      3601194.0
# 99634  Still the Best Hope: Why the World Needs Ameri...      1243920.0
# 99635  Wicca: Living a Magical Life: A Guide to Initi...      3815416.0
# 99636                               The Shepherd's Crown      3788828.0
# 99637  George Muller: The Guardian of Bristol's Orpha...       119460.0
# 99638                  The Golden Ass (Penguin Classics)      1385520.0
# 99639  21st Century Communication 2: Listening, Speak...      3290142.0
# 99640  Eat to Beat Disease: The New Science of How Yo...      4031850.0
# 99641  We Are All Weird: The Myth of Mass and the End...      3788616.0
# 99642  Introduction to Topology: Third Edition (Dover...       119040.0
# 99643                                           Tumbling      3800040.0
# 99644  All Points Patchwork: English Paper Piecing be...      2225100.0
# 99646  Voices From The Past - Puritan Devotional Read...      2344086.0
# 99647                                     With This Ring      3762792.0
# 99648  Harry Potter e i Doni della Morte (Harry Potte...      3857212.0
# 99649                      Death and the Redheaded Woman      3787020.0
# 99650                          Seeing Through Statistics      1762620.0
# 99651  Yeah Baby!: The Modern Mama's Guide to Masteri...      3052216.0
# 99652  NIV, Kids' Visual Study Bible, Leathersoft, Te...      3138260.0
# 99653  The Sun Does Shine: How I Found Life and Freed...      3819444.0
# 99654  Self Help for Your Nerves : Learn to Relax and...       143220.0
# 99656  The Politically Incorrect Guide to Christianit...      3803892.0
# 99657                 Learning to Love Yourself Workbook       143220.0
#
#                        type  sales_rank    price  language_1  \
# 2              EBOOK_BUNDLE         2.0    698.0     English
# 5              EBOOK_BUNDLE         3.0   3697.0     English
# 9              EBOOK_BUNDLE         5.0   2347.0     English
# 11             EBOOK_BUNDLE         4.0   1597.0     English
# 13       DOWNLOADABLE_AUDIO        11.0   1995.0     English
# 14             EBOOK_BUNDLE         4.0    897.0     English
# 15             EBOOK_BUNDLE         4.0   1845.0     English
# 20                ABIS_BOOK      7165.0   2069.0     English
# 23       DOWNLOADABLE_AUDIO       183.0   1795.0     English
# 25     BOOKS_1973_AND_LATER      2459.0   2700.0     English
# 29                ABIS_BOOK        83.0   1526.0     English
# 36                ABIS_BOOK        30.0   1563.0     English
# 38       DOWNLOADABLE_AUDIO        20.0   2999.0     English
# 39       DOWNLOADABLE_AUDIO        30.0   2999.0     English
# 41       DOWNLOADABLE_AUDIO       198.0   2495.0     English
# 42       DOWNLOADABLE_AUDIO       128.0   2195.0     English
# 44       DOWNLOADABLE_AUDIO        24.0   4195.0     English
# 46       DOWNLOADABLE_AUDIO        21.0   2999.0     English
# 47                ABIS_BOOK      2120.0   1218.0     English
# 50       DOWNLOADABLE_AUDIO        20.0   4499.0     English
# 56       DOWNLOADABLE_AUDIO        25.0   4499.0     English
# 60       DOWNLOADABLE_AUDIO        58.0   2399.0     English
# 61       DOWNLOADABLE_AUDIO        39.0   4499.0     English
# 62       DOWNLOADABLE_AUDIO        41.0   4499.0     English
# 63       DOWNLOADABLE_AUDIO        43.0    696.0     English
# 64                ABIS_BOOK        30.0    599.0     English
# 65                ABIS_BOOK        34.0    932.0     English
# 67       DOWNLOADABLE_AUDIO       772.0   2899.0     English
# 68                ABIS_BOOK        78.0   1570.0     English
# 69       DOWNLOADABLE_AUDIO     29011.0    608.0     English
# ...                     ...         ...      ...         ...
# 99625             ABIS_BOOK     45929.0   1213.0     English
# 99626             ABIS_BOOK    163427.0   1041.0     English
# 99627             ABIS_BOOK     83020.0    401.0     English
# 99628             ABIS_BOOK    493204.0   2335.0     English
# 99629    DOWNLOADABLE_AUDIO     50128.0   1695.0     English
# 99630             ABIS_BOOK     29242.0    748.0     English
# 99631             ABIS_BOOK     60988.0  15685.0     English
# 99633             ABIS_BOOK      2170.0   1896.0     English
# 99634             ABIS_BOOK    109242.0   1344.0     English
# 99635    DOWNLOADABLE_AUDIO     62646.0    599.0     English
# 99636    DOWNLOADABLE_AUDIO     62952.0   2209.0     English
# 99637             ABIS_BOOK     33000.0    807.0     English
# 99638             ABIS_BOOK     28505.0   1176.0     English
# 99639             ABIS_BOOK    381919.0   4872.0     English
# 99640             ABIS_BOOK    233023.0   2869.0     English
# 99641    DOWNLOADABLE_AUDIO     54589.0    899.0     English
# 99642             ABIS_BOOK     36488.0    687.0     English
# 99643    DOWNLOADABLE_AUDIO    105467.0   2695.0     English
# 99644             ABIS_BOOK     12690.0   1397.0     English
# 99646             ABIS_BOOK     69812.0   2634.0     English
# 99647    DOWNLOADABLE_AUDIO     73286.0   2395.0     English
# 99648    DOWNLOADABLE_AUDIO     57319.0   4499.0     Italian
# 99649    DOWNLOADABLE_AUDIO     80495.0   1795.0     English
# 99650             ABIS_BOOK    241489.0  15061.0     English
# 99651             ABIS_BOOK     16247.0   1101.0     English
# 99652             ABIS_BOOK     14523.0   3056.0     English
# 99653             ABIS_BOOK    210964.0   1399.0     English
# 99654             ABIS_BOOK    162785.0   1411.0     English
# 99656    DOWNLOADABLE_AUDIO    138957.0   1495.0     English
# 99657             ABIS_BOOK     78841.0   1435.0     English
#
#               language_2
# 2              Published
# 5              Published
# 9              Published
# 11             Published
# 13             Published
# 14             Published
# 15             Published
# 20             Published
# 23             Published
# 25             Published
# 29             Published
# 36             Published
# 38             Published
# 39             Published
# 41             Published
# 42             Published
# 44             Published
# 46             Published
# 47             Published
# 50             Published
# 56             Published
# 60             Published
# 61             Published
# 62             Published
# 63             Published
# 64             Published
# 65             Published
# 67             Published
# 68             Published
# 69             Published
# ...                  ...
# 99625          Published
# 99626          Published
# 99627          Published
# 99628          Published
# 99629          Published
# 99630          Published
# 99631          Published
# 99633          Published
# 99634          Published
# 99635          Published
# 99636          Published
# 99637          Published
# 99638          Published
# 99639          Published
# 99640          Published
# 99641          Published
# 99642          Published
# 99643  Original Language
# 99644          Published
# 99646          Published
# 99647          Published
# 99648          Published
# 99649          Published
# 99650          Published
# 99651          Published
# 99652          Published
# 99653          Published
# 99654          Published
# 99656  Original Language
# 99657          Published
#
# [89493 rows x 52 columns]

# %%
duplicates.describe(include='all')
# Out:
#                   label     manufacturer        publisher           studio
# count             99600            99600            99600            99600
# unique            10107            10107            10107            10107
# top     Audible Studios  Audible Studios  Audible Studios  Audible Studios
# freq               4267             4267             4267             4267

# %%
df.duplicated(subset=['label', 'manufacturer', 'publisher', 'studio'],keep='first').value_counts()
# Out:
# True     89493
# False    10107
# dtype: int64

# %% [markdown]
# Since the above 4 columns contain duplicated informartion in 89493 out of 99600 total records we can keep one of those and drop the reamining ones without losing useful information.

# %%
# Keep publisher and drop the rest
df.drop(['label', 'manufacturer','studio'], axis =1, inplace=True)

# %%
df.shape
# Out:
# (99600, 49)

# %%
#df.describe(include='all').transpose()

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Outlier detection and transformation

# %% [markdown]
# Before we decide whether to use standard deviation or interquntile range to identify outliers, lets plot the data points using a distribution plot.

# %%
def distWithBox(data):
    import numpy as np
    import seaborn as sns
    import matplotlib.pyplot as plt

    sns.set(style="ticks")

    x = df[data]

    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                        gridspec_kw={"height_ratios": (.15, .85)})

    sns.boxplot(x, ax=ax_box)
    sns.distplot(x, ax=ax_hist)

    ax_box.set(yticks=[])
    sns.despine(ax=ax_hist)
    sns.despine(ax=ax_box, left=True)

# %%
## Distribution and box plot of the raw data with outliers
distWithBox('price')

# %% [markdown]
# For normally distributed data, the skewness should be about 0. A skewness value > 0 means that there is more weight in the left tail of the distribution. The function skewtest can be used to determine if the skewness value is close enough to 0, statistically speaking.

# %%
from scipy.stats import skew
from scipy.stats import skewtest
skew(df['price'])
# Out:
# 49.71356722842451

# %%
import seaborn as sns
sns.set(style="whitegrid")
ax = sns.boxplot(x=df['price'])

# %% [markdown]
# We can see from the the distribution plot, the skewtest and the box plot that price is not normally distributed. The price  data is right skewed and there are outlier values that need to be handled.
#
# When a data set has outliers or extreme values, we summarize a typical value using the median as opposed to the mean.  When a data set has outliers, variability is often summarized by a statistic called the interquartile range, which is the difference between the first and third quartiles. The first quartile, denoted Q1, is the value in the data set that holds 25% of the values below it. The third quartile, denoted Q3, is the value in the data set that holds 25% of the values above it. The quartiles can be determined following the same approach that we used to determine the median, but we now consider each half of the data set separately. The interquartile range is defined as follows:
#
# Interquartile Range(IQR) = Q3-Q1
#
# Outliers are values  1.5*IQR below Q1 or above Q3 or equivalently, values below Q1-1.5 IQR or above Q3+1.5 IQR.
# These are referred to as Tukey fences.

# %%
from numpy import percentile
data=df['price']
q25, q75 = percentile(data, 25), percentile(data, 75)
iqr = q75 - q25
print('Percentiles:\n\t25th=%.3f \n\t75th=%.3f \n\tIQR=%.3f' % (q25, q75, iqr))
# calculate the outlier cutoff
cut_off = iqr * 1.5
lower, upper = q25 - cut_off, q75 + cut_off
# identify outliers
outliers = [x for x in data if x < lower or x > upper]
print('Identified outliers: %d' % len(outliers) )
outliers_removed = [x for x in data if x >= lower and x <= upper]
print('Non-outlier observations: %d' % len(outliers_removed))
# Out:
# Percentiles:
# 	25th=1045.000
# 	75th=2195.000
# 	IQR=1150.000
# Identified outliers: 4619
# Non-outlier observations: 94981

# %%
outliers=[] 
data_1=df['price'] 
for item in data_1:
    if item <lower or item>upper:
        outliers.append(item)

# %%
x=df['price']
outlier_indices=list(data_1.index[(x<lower) | (x> upper)])

# %%
len(outlier_indices)
# Out:
# 4619

# %%
df.drop(axis=0,index=outlier_indices, inplace=True)

# %%
df.shape
# Out:
# (94981, 49)

# %%
## lets plot distribution with and box plot to see the change after we trim down the outliers
distWithBox('price')

# %% [markdown]
# ### Correlation Between Numerical Features

# %%
cor=df.corr()
sns.heatmap(cor,cmap="PiYG")

# %% [markdown]
# Box Plots to show distribution of unique values within categorical features against price.

# %%
sns.boxplot(x=df['price'],y=df['binding'], data=df)

# %%
sns.boxplot(y=df['language_1'],x=df['price'], data=df)

# %% [markdown]
# ## Encoding categorical columns

# %%
cat_cols=['author','language_1','language_2','binding','categoryTree_0', 'categoryTree_1', 'categoryTree_2', 'categoryTree_3',
       'categoryTree_4','productGroup','publisher','title','type','language_1','language_2']

# %%
for item in cat_cols:
    df[item]=df[item].astype(str)

# %%
df[cat_cols].head()

# %%
#df.dtypes

# %%
# Label encoding to convert string to representative numeric values
df[cat_cols]= df[cat_cols].apply(LabelEncoder().fit_transform)

# %%
# Display top 5 records from the dataset to check if all the records are converted to numbers
df.head(5)
# Out:
#    productType  author  availabilityAmazon  binding  categoryTree_0  \
# 0            0   12785                 0.0        5               1
# 1            0   33900                -1.0        4               1
# 2            0     596                -1.0        4               1
# 3            0   25548                 0.0        5               1
# 4            0    8688                 0.0        5               1
#
#    categoryTree_1  categoryTree_2  categoryTree_3  categoryTree_4  domainId  \
# 0              14              17             112             240         1
# 1              14               4              14              97         1
# 2              14               7             211             582         1
# 3              14               1              97              17         1
# 4              14              17             112             130         1
#
#       ...      stats_outOfStockPercentage30  stats_outOfStockPercentage90  \
# 0     ...                               0.0                           0.0
# 1     ...                             100.0                         100.0
# 2     ...                             100.0                         100.0
# 3     ...                               0.0                           0.0
# 4     ...                               0.0                           0.0
#
#    stats_outOfStockPercentageInInterval  title  trackingSince  type  \
# 0                                   0.0  86710      4103352.0     0
# 1                                 100.0  51306      4135600.0    17
# 2                                 100.0  70847      4079996.0    17
# 3                                   1.0   8413      3762476.0     0
# 4                                   0.0  86708      3836972.0     0
#
#    sales_rank   price  language_1  language_2
# 0      1945.0  1599.0           1           4
# 1         1.0  3094.0           1           4
# 2         2.0   698.0           1           4
# 3      3568.0  1788.0           1           4
# 4        32.0  1670.0           1           4
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# VarianceThreshold is a simple baseline approach to feature selection. It removes all features whose variance doesn’t meet some threshold. By default, it removes all zero-variance features, i.e. features that have the same value in all samples.
#
# threshold .8 * (1 - .8)
#
# Using 0.8 as a threshhold, we will remove features with less than 20 percent variation within itself.

# %%
noStats=['productType', 'author', 'availabilityAmazon', 'binding',
       'categoryTree_0', 'categoryTree_1', 'categoryTree_2', 'categoryTree_3',
       'categoryTree_4', 'domainId', 'hasReviews',
       'isEligibleForSuperSaverShipping', 'isEligibleForTradeIn',
       'isRedirectASIN', 'isSNS', 'lastPriceChange', 'lastRatingUpdate',
       'lastUpdate', 'listedSince', 'newPriceIsMAP', 'numberOfItems',
       'numberOfPages', 'offersSuccessful', 'packageHeight', 'packageLength',
       'packageQuantity', 'packageWeight', 'packageWidth', 'productGroup',
       'publicationDate', 'publisher', 'releaseDate', 'rootCategory',
       'stats_outOfStockPercentage30',
       'stats_outOfStockPercentage90', 'stats_outOfStockPercentageInInterval',
       'title', 'trackingSince', 'type', 'sales_rank', 'language_1',
       'language_2']
df_X=df[noStats]

# %%
#df_X=df.loc[:, df.columns not in'stats_atIntervalStart', 'stats_avg','stats_avg30', 'stats_avg90', 'stats_avg180', 'stats_current','price']]
df_y=df['price']

# %%
from sklearn.feature_selection import VarianceThreshold
print('%s Number of features before VarianceThreshhold'%len(df_X.columns))

selector=VarianceThreshold(threshold=(.8*(1-.8)))
FeaturesTransformed=selector.fit_transform(df_X)

## print the support and shape of the transformed features
print(selector.get_support())
# Out:
# 42 Number of features before VarianceThreshhold
# [ True  True False  True False False  True  True  True False False  True
#  False False False  True  True  True  True False  True  True False  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False]

# %%
data=df_X[df_X.columns[selector.get_support(indices=True)]]
cols=data.columns

# %%
df_reduced=pd.DataFrame(FeaturesTransformed, columns=cols)
df_reduced.shape
# Out:
# (94981, 31)

# %%
data=df_reduced
target=df_y

# %%
data.shape
# Out:
# (94981, 31)

# %%
from yellowbrick.target import FeatureCorrelation
feature_names = np.array(df.columns)
data=data
target=target
visualizer = FeatureCorrelation(labels=feature_names)
visualizer.fit(data, target)
visualizer.poof()

# %%
df.dtypes.value_counts()
# Out:
# float64    34
# int32      13
# int64       2
# dtype: int64

# %% [markdown]
# cor=df.corr()
# sns.heatmap(cor,cmap="PiYG")

# %% [markdown]
# sns.boxplot(x=df['binding'], y=df['price'], data=df)

# %% [markdown]
# sns.boxplot(x=df['language_1'],y=df['price'], data=df)

# %% [markdown]
# sns.boxplot(x=df['language_2'],y=df['price'], data=df)

# %% [markdown]
# # Yellowbrick for Feature Selection
#
# we are using yellowbrick's feature selection method for finding and selecting the most useful features and eliminate zero importance features from the dataset.

# %% [markdown]
# ### Important Features for Random Forest Regressor

# %%
#Using yellowbrick feature selection method with random forest regressor
from sklearn.ensemble import RandomForestRegressor

from yellowbrick.features.importances import FeatureImportances

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot()

viz = FeatureImportances(RandomForestRegressor(), ax=ax)
viz.fit(data, target)
viz.poof()

# %%
feature_importances = pd.DataFrame(viz.feature_importances_,
                                   index=data.columns,
                                   columns=['importance']).sort_values('importance', ascending=False)

# %%
## important features for Random Forest Regression
RF_importants=feature_importances.index[feature_importances.importance!=0]

# %%
df[RF_importants].shape
# Out:
# (94981, 31)

# %%
# predicting price using random forest regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split as split
X=df[RF_importants]
Y=df['price']
model=RandomForestRegressor()
X_train, X_test, Y_train, Y_test= split(X,Y,test_size=0.25, random_state=42)
model.fit(X_train,Y_train)
Y_test=model.predict(X_test)

# %%
ax1=sns.distplot(target,hist=False, color='r',label="Actual price")
sns.distplot(Y_test,hist=False,color='b', label="Predicted price", ax=ax1)
plt.title(" Actual Vs Predicted Price ")
plt.xlabel('Price')
plt.ylabel('Proportion of Books')
plt.show()

# %% [markdown]
# ### Important Features for Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

from yellowbrick.features.importances import FeatureImportances

fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot()

viz = FeatureImportances(GradientBoostingRegressor(), ax=ax)
viz.fit(data, target)
viz.poof()

# %%
feature_importances = pd.DataFrame(viz.feature_importances_,
                                   index=data.columns,
                                   columns=['importance']).sort_values('importance', ascending=False)

# %%
## important features for gradient boosting regression
GBR_importants=feature_importances.index[feature_importances.importance!=0]

# %%
df[GBR_importants].shape
# Out:
# (94981, 25)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split as split
X=df[GBR_importants]
Y=df['price']
model=GradientBoostingRegressor()
X_train, X_test, Y_train, Y_test= split(X,Y,test_size=0.25, random_state=42)
model.fit(X_train,Y_train)
Y_test=model.predict(X_test)

# %%
ax1=sns.distplot(target,hist=False, color='r',label="Actual price")
sns.distplot(Y_test,hist=False,color='b', label="Predicted price", ax=ax1)
plt.title(" Actual Vs Predicted Price ")
plt.xlabel('Price')
plt.ylabel('Proportion of Books')
plt.show()

# %% [markdown]
# ### Important Features for Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

from yellowbrick.features.importances import FeatureImportances

fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot()

viz = FeatureImportances( DecisionTreeRegressor(), ax=ax)
viz.fit(data, target)
viz.poof()

# %%
feature_importances = pd.DataFrame(viz.feature_importances_,
                                   index=data.columns,
                                   columns=['importance']).sort_values('importance', ascending=False)

# %%
## important features for decision tree regression
DTR_importants=feature_importances.index[feature_importances.importance!=0]

# %%
df[DTR_importants].shape
# Out:
# (94981, 31)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split as split
X=df[DTR_importants]
Y=df['price']
model=DecisionTreeRegressor()
X_train, X_test, Y_train, Y_test= split(X,Y,test_size=0.25, random_state=42)
model.fit(X_train,Y_train)
Y_test=model.predict(X_test)

# %%
ax1=sns.distplot(target,hist=False, color='r',label="Actual price")
sns.distplot(Y_test,hist=False,color='b', label="Predicted price", ax=ax1)
plt.title(" Actual Vs Predicted Price ")
plt.xlabel('Price')
plt.ylabel('Proportion of Books')
plt.show()

# %% [markdown]
# ## Model Development
# In this section we will implement several models that will predict price using the dependent variables and compare the accuracy, r-score, goodness of fit and plot residuals. Based on the scores and visual comparison of the plots, we will refine the best performing models using grid search to fine tune the hyperparameters to generate a better predictive model.

# %%
# This function applies multiple models on the data and returns model name with r2-score and mean squared error value
def ModelScores(data,target):
    X=data
    Y=target
    
    from sklearn.metrics import r2_score
    from sklearn.metrics import mean_squared_error
    import math
    from sklearn.model_selection import train_test_split as split
    X_train, X_test, Y_train, Y_test= split(X,Y,test_size=0.25, random_state=42)
    
    from sklearn.ensemble import GradientBoostingRegressor
    from sklearn.ensemble import RandomForestRegressor
    from sklearn.tree import DecisionTreeRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import RidgeCV
    from sklearn.linear_model import LassoLars
    from sklearn.linear_model import Lasso
    from sklearn.linear_model import ElasticNet
    from sklearn.linear_model import BayesianRidge
    from sklearn.linear_model import RANSACRegressor

    models={'Gradient Boost': GradientBoostingRegressor(),
            'Random Forest': RandomForestRegressor(),
            'Decision Tree': DecisionTreeRegressor(),
            'Linear Regression': LinearRegression(),
            'MLP': MLPRegressor(),
            'Ridge CV': RidgeCV(),
            'LassoLars':LassoLars(),
            'Lasso':Lasso(),
            'Elastic Search': ElasticNet(),
            'Bayesian Ridge':BayesianRidge(),
            'Ransac':RANSACRegressor()      
           }
    for name,model in models.items():
        mdl=model
        mdl.fit(X_train, Y_train)
        prediction = mdl.predict(X_test)
        print(name)
        print("Accuracy Score", r2_score(Y_test, prediction))
        mse3 = mean_squared_error(Y_test, prediction)
        print("The root mean square value", math.sqrt(mse3))

# %%
data=data
target=df['price']
ModelScores(data, target)
# Out:
# Gradient Boost
# Accuracy Score 0.5084506168385858
# The root mean square value 520.5622894842388
# Random Forest
# Accuracy Score 0.5782937079891288
# The root mean square value 482.1633174022697
# Decision Tree
# Accuracy Score 0.20958879936337005
# The root mean square value 660.109022787755
# Linear Regression
# Accuracy Score -153059694567804.1
# The root mean square value 9185854186.02231
# MLP
# Accuracy Score -2.020942115012304e+24
# The root mean square value 1055519019396691.2
# Ridge CV
# Accuracy Score -6.546182591705557e+26
# The root mean square value 1.8996919548474504e+16
# LassoLars
# Accuracy Score 0.008600202977327998
# The root mean square value 739.2877992053319
# Lasso
# Accuracy Score -179542000920381.44
# The root mean square value 9948833357.822216
# Elastic Search
# Accuracy Score -511573857348186.94
# The root mean square value 16793580388.410753
# Bayesian Ridge
# Accuracy Score -157128547104517.44
# The root mean square value 9307149145.764828
# Ransac
# Accuracy Score -1.531698301980787e+21
# The root mean square value 29058670571461.89

# %%
# %matplotlib inline
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.regressor import ResidualsPlot
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor

regressors = {
    "support vector machine": SVR(),
    "Gradient Boost": GradientBoostingRegressor(),
    "Random Forest": RandomForestRegressor(),
    "Decision Tree": DecisionTreeRegressor()
    
}

for _, regressor in regressors.items():
    visualizer = ResidualsPlot(regressor)
    visualizer.fit(X_train, Y_train)
    visualizer.score(X_test, Y_test)
    visualizer.poof()

# %%
from yellowbrick.target import FeatureCorrelation
feature_names = np.array(df.columns)
data=df.loc[:, df.columns != 'price']
target=df['price']
figsize=(20, 20)
visualizer = FeatureCorrelation(labels=feature_names)
visualizer.fit(data, target)
visualizer.poof()

# %%
#validation curve for decision tree regression and Random forest regression models

from yellowbrick.model_selection import ValidationCurve

# Extract the instances and target
X = df_X
y = df_y

regressors = {
        "Gradient Boost": GradientBoostingRegressor(),
        "Decision Tree": DecisionTreeRegressor(),
        "Random Forest": RandomForestRegressor()

}
for _, regressor in regressors.items():
    viz = ValidationCurve(
        regressor, param_name="max_depth",
        param_range=np.arange(1, 11), cv=10, scoring="r2"
    )
    # Fit and poof the visualizer
    viz.fit(X, y)
    viz.poof()

# %% [markdown]
# We will use the validation curve from the above thee figures to narrow down the optimal 'max_depth' value range to use, for hyperparameter tuning in a  grid search.

# %%
# Cross Validation Score for Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from yellowbrick.model_selection import CVScores

ind=df[RF_importants].values
dep=df['price'].values

_, ax = plt.subplots()
cv = KFold(10)
oz = CVScores(
    RandomForestRegressor(), ax=ax, cv=cv, scoring='r2'
)

oz.fit(ind, dep)
oz.poof()

# %%
# CV score for Gradiet Boosting Regresor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores

ind=df[GBR_importants].values
dep=df['price'].values

_, ax = plt.subplots()
cv = StratifiedKFold(n_splits=10, random_state=42)
oz = CVScores(
    GradientBoostingRegressor(), ax=ax, cv=cv, scoring = 'r2'
)

oz.fit(ind, dep)
oz.poof()

# %%
# CV score for Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import KFold
from yellowbrick.model_selection import CVScores

ind=df[DTR_importants].values
dep=df['price'].values

_, ax = plt.subplots()
cv = KFold(10)
oz = CVScores(
    DecisionTreeRegressor(), ax=ax, cv=cv, scoring = 'r2'
)

oz.fit(ind, dep)
oz.poof()

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# hyper-parameter tunung for decision tree
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

DecisionTree = DecisionTreeRegressor(random_state = 40)

min_samples_split = [2,3,4,5,6,7,8]
min_samples_leaf = [1,2,3,4,5]
max_depth = [4,5,6,7,8,9]
tuned_params = [{'min_samples_split': min_samples_split}, {'min_samples_leaf': min_samples_leaf},{'max_depth': max_depth}]
n_folds = 5

X=df[DTR_importants]
Y=df['price']

grid = GridSearchCV(
    DecisionTree, tuned_params, cv=n_folds
)

grid.fit(X, Y)
print(grid.best_estimator_)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=9, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=40, splitter='best')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

GradientBoosting = GradientBoostingRegressor(random_state = 40)
alphas = [0.001, 0.01, 0.1, 0.5, 0.9]
sample_split = [2,3,4,5,6,7,8]
max_depth = [4,5,6,7,8,9]
learning_rate = [0.1, 0.3, 0.5, 0.7]
tuned_params = [{'alpha': alphas}, {'min_samples_split': sample_split}, {'max_depth': max_depth}, {'learning_rate':learning_rate}]
n_folds = 5

X=df[GBR_importants]
Y=df['price']

grid = GridSearchCV(
    GradientBoosting, tuned_params, cv=n_folds
)

grid.fit(X, Y)
print(grid.best_estimator_)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=9, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, n_iter_no_change=None, presort='auto',
#              random_state=40, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

RandomForest = RandomForestRegressor(random_state = 40)

estimators = [10,50,100]
sample_split = [2,3,4,5,6,7,8]
sample_leaf = [1,2,3,4,5]
max_depth = [4,5,6,7,8,9]
tuned_params = [{'n_estimators': estimators}, {'min_samples_split': sample_split}, {'min_samples_leaf': sample_leaf},{'max_leaf_nodes': max_depth}]
n_folds = 5

X=df[RF_importants]
Y=df['price']

grid = GridSearchCV(
    RandomForest, tuned_params, cv=n_folds
)

grid.fit(X, Y)
print(grid.best_estimator_)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=40, verbose=0, warm_start=False)

# %% [markdown]
# ## Model Evaluation
# In this part we are using the result that we obtained from the grid search as an input to retrain our models. The grid search is applied with cross validation by taking the average score over 12 folds.

# %%
X=df[DTR_importants]
Y=df['price']
X_train, X_test, Y_train, Y_test= split(X,Y,test_size=0.25, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor(criterion='mse', max_depth=9, max_features=None,
           max_leaf_nodes=None, min_impurity_decrease=0.0,
           min_impurity_split=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           presort=False, random_state=40, splitter='best')

model.fit(X_train,Y_train)
prediction13 = model.predict(X_test)
print("Accuracy Score", r2_score(Y_test, prediction13))
mse = mean_squared_error(Y_test, prediction13)
print("The root mean square value", math.sqrt(mse))
# Out:
# Accuracy Score 0.49977046148182247
# The root mean square value 525.1384194253062

# %%
X=df[GBR_importants]
Y=df['price']
X_train, X_test, Y_train, Y_test= split(X,Y,test_size=0.25, random_state=42)

from sklearn.ensemble import GradientBoostingRegressor
model=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
             learning_rate=0.1, loss='ls', max_depth=5, max_features=None,
             max_leaf_nodes=None, min_impurity_decrease=0.0,
             min_impurity_split=None, min_samples_leaf=1,
             min_samples_split=2, min_weight_fraction_leaf=0.0,
             n_estimators=100, n_iter_no_change=None, presort='auto',
             random_state=40, subsample=1.0, tol=0.0001,
             validation_fraction=0.1, verbose=0, warm_start=False)
model.fit(X_train,Y_train)
prediction13 = model.predict(X_test)
print("Accuracy Score", r2_score(Y_test, prediction13))
mse = mean_squared_error(Y_test, prediction13)
print("The root mean square value", math.sqrt(mse))
# Out:
# Accuracy Score 0.5429570627527162
# The root mean square value 501.95828536986414

# %%
X=df[RF_importants]
Y=df['price']
X_train, X_test, Y_train, Y_test= split(X,Y,test_size=0.25, random_state=42)

from sklearn.ensemble import RandomForestRegressor
rfg = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
           max_features='auto', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
           oob_score=False, random_state=40, verbose=0, warm_start=False)
rfg.fit(X_train, Y_train)
prediction14 = rfg.predict(X_test)
print("Accuracy Score", r2_score(Y_test, prediction14))
mse2 = mean_squared_error(Y_test, prediction14)
print("The root mean square value", math.sqrt(mse2))
# Out:
# Accuracy Score 0.6150831745011749
# The root mean square value 460.6515892073408

# %% [markdown]
# http://sphweb.bumc.bu.edu/otlt/mph-modules/bs/bs704_summarizingdata/bs704_summarizingdata7.html
